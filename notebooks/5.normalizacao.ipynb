# %% [markdown]
# # Imports

# %%
import pandas as pd
import os
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

# %% [markdown]
# # Configs

# %%
df_enade = pd.read_csv("../enade_ready_to_use/enade_pós-process_18-23.csv", encoding="utf-8-sig", low_memory=False)

df_municipios = pd.read_csv("../enade_ready_to_use/municipios.csv", encoding="utf-8-sig", low_memory=False)
df_cursos = pd.read_csv("../enade_ready_to_use/cursos.csv", encoding="utf-8-sig", low_memory=False)

# %%
df_desnormalizado = df_enade.merge(df_municipios, on="id_municipio", how="left").merge(df_cursos, on="id_curso", how="left")

# %%
ordem = [
    "id_curso",
    "nome_curso",
    "categoria_administrativa",
    "modalidade_graduacao",
    "turno_graduacao",
    
    "ano_enade",
    
    
    "id_municipio",
    "nome_municipio",
    "uf",
    "regiao",

    "sexo",
    "idade",
    "cor_raca",

    "ano_fim_ensino_medio",
    "ano_ingresso_graduacao",
    "tipo_escola_ensino_medio",
    "primeira_geracao",
    "escolaridade_pai",
    "escolaridade_mae",
    "motivacao_curso",
    "renda_familiar",
    "horas_trabalho",
    "cotas",

    "nota_geral",
    "nota_formacao_geral",
    "nota_componentes_especifico",

    "avaliacao_dificuldade_fg",
    "avaliacao_dificuldade_ce",
    "avaliacao_equipamentos",
    "avaliacao_ambiente"

    
]

# %%
df_desnormalizado = df_desnormalizado[ordem]

# %%
df_desnormalizado.insert(0, "id_participacao", range(1, len(df_desnormalizado) + 1))

# %%
df_desnormalizado.head(20)
# Out:
#     id_participacao  id_curso nome_curso categoria_administrativa  \
# 0                 1         2    Direito          Pública Federal
# 1                 2         2    Direito          Pública Federal
# 2                 3         2    Direito          Pública Federal
# 3                 4         2    Direito          Pública Federal
# 4                 5         2    Direito          Pública Federal
# 5                 6         2    Direito          Pública Federal
# 6                 7         2    Direito          Pública Federal
# 7                 8         2    Direito          Pública Federal
# 8                 9         2    Direito          Pública Federal
# 9                10         2    Direito          Pública Federal
# 10               11         2    Direito          Pública Federal
# 11               12         2    Direito          Pública Federal
# 12               13         2    Direito          Pública Federal
# 13               14         2    Direito          Pública Federal
# 14               15         2    Direito          Pública Federal
# 15               16         2    Direito          Pública Federal
# 16               17         2    Direito          Pública Federal
# 17               18         2    Direito          Pública Federal
# 18               19         2    Direito          Pública Federal
# 19               20         2    Direito          Pública Federal
#
#    modalidade_graduacao turno_graduacao  ano_enade  id_municipio  \
# 0            Presencial         Noturno       2018       5103403
# 1            Presencial         Noturno       2018       5103403
# 2            Presencial        Matutino       2018       5103403
# 3            Presencial         Noturno       2018       5103403
# 4            Presencial         Noturno       2018       5103403
# 5            Presencial         Noturno       2018       5103403
# 6            Presencial         Noturno       2018       5103403
# 7            Presencial         Noturno       2018       5103403
# 8            Presencial         Noturno       2018       5103403
# 9            Presencial         Noturno       2018       5103403
# 10           Presencial         Noturno       2018       5103403
# 11           Presencial         Noturno       2018       5103403
# 12           Presencial         Noturno       2018       5103403
# 13           Presencial         Noturno       2018       5103403
# 14           Presencial         Noturno       2018       5103403
# 15           Presencial         Noturno       2018       5103403
# 16           Presencial         Noturno       2018       5103403
# 17           Presencial         Noturno       2018       5103403
# 18           Presencial         Noturno       2018       5103403
# 19           Presencial         Noturno       2018       5103403
#
#    nome_municipio  uf        regiao sexo  idade cor_raca  \
# 0          CUIABA  MT  Centro-Oeste    F    NaN   Branca
# 1          CUIABA  MT  Centro-Oeste    F    NaN   Branca
# 2          CUIABA  MT  Centro-Oeste    F    NaN   Branca
# 3          CUIABA  MT  Centro-Oeste    F    NaN   Branca
# 4          CUIABA  MT  Centro-Oeste    F    NaN   Branca
# 5          CUIABA  MT  Centro-Oeste    F   17.0   Branca
# 6          CUIABA  MT  Centro-Oeste    F   17.0   Branca
# 7          CUIABA  MT  Centro-Oeste    F   18.0   Branca
# 8          CUIABA  MT  Centro-Oeste    F   18.0   Branca
# 9          CUIABA  MT  Centro-Oeste    F   18.0   Branca
# 10         CUIABA  MT  Centro-Oeste    F   18.0   Branca
# 11         CUIABA  MT  Centro-Oeste    F   18.0   Branca
# 12         CUIABA  MT  Centro-Oeste    F   18.0   Branca
# 13         CUIABA  MT  Centro-Oeste    F   18.0   Branca
# 14         CUIABA  MT  Centro-Oeste    F   18.0   Branca
# 15         CUIABA  MT  Centro-Oeste    F   18.0   Branca
# 16         CUIABA  MT  Centro-Oeste    F   18.0   Branca
# 17         CUIABA  MT  Centro-Oeste    F   18.0   Branca
# 18         CUIABA  MT  Centro-Oeste    F   18.0   Branca
# 19         CUIABA  MT  Centro-Oeste    F   18.0   Branca
#
#     ano_fim_ensino_medio  ano_ingresso_graduacao tipo_escola_ensino_medio  \
# 0                    NaN                  2014.0   Todo em escola pública
# 1                    NaN                  2013.0   Todo em escola pública
# 2                    NaN                  2013.0   Todo em escola pública
# 3                    NaN                  2014.0   Todo em escola pública
# 4                    NaN                  2015.0   Todo em escola pública
# 5                    NaN                  2015.0   Todo em escola pública
# 6                    NaN                  2015.0   Todo em escola pública
# 7                    NaN                  2015.0   Todo em escola pública
# 8                    NaN                  2016.0   Todo em escola pública
# 9                    NaN                  2014.0   Todo em escola pública
# 10                   NaN                  2015.0   Todo em escola pública
# 11                   NaN                  2015.0   Todo em escola pública
# 12                   NaN                  2014.0   Todo em escola pública
# 13                   NaN                  2016.0   Todo em escola pública
# 14                   NaN                  2015.0   Todo em escola pública
# 15                   NaN                  2014.0   Todo em escola pública
# 16                   NaN                  2014.0   Todo em escola pública
# 17                   NaN                  2014.0   Todo em escola pública
# 18                   NaN                  2014.0   Todo em escola pública
# 19                   NaN                  2014.0   Todo em escola pública
#
#    primeira_geracao escolaridade_pai escolaridade_mae  \
# 0               Sim          Nenhuma          Nenhuma
# 1               Sim          Nenhuma          Nenhuma
# 2               Sim          Nenhuma          Nenhuma
# 3               Sim          Nenhuma          Nenhuma
# 4               Sim          Nenhuma          Nenhuma
# 5               Sim          Nenhuma          Nenhuma
# 6               Sim          Nenhuma          Nenhuma
# 7               Sim          Nenhuma          Nenhuma
# 8               Sim          Nenhuma          Nenhuma
# 9               Sim          Nenhuma          Nenhuma
# 10              Sim          Nenhuma          Nenhuma
# 11              Sim          Nenhuma          Nenhuma
# 12              Sim          Nenhuma          Nenhuma
# 13              Sim          Nenhuma          Nenhuma
# 14              Sim          Nenhuma          Nenhuma
# 15              Sim          Nenhuma          Nenhuma
# 16              Sim          Nenhuma          Nenhuma
# 17              Sim          Nenhuma          Nenhuma
# 18              Sim          Nenhuma          Nenhuma
# 19              Sim          Nenhuma          Nenhuma
#
#                     motivacao_curso          renda_familiar  \
# 0   Inserção no mercado de trabalho  Até 1,5 salário mínimo
# 1   Inserção no mercado de trabalho  Até 1,5 salário mínimo
# 2   Inserção no mercado de trabalho  Até 1,5 salário mínimo
# 3   Inserção no mercado de trabalho  Até 1,5 salário mínimo
# 4   Inserção no mercado de trabalho  Até 1,5 salário mínimo
# 5   Inserção no mercado de trabalho  Até 1,5 salário mínimo
# 6   Inserção no mercado de trabalho  Até 1,5 salário mínimo
# 7   Inserção no mercado de trabalho  Até 1,5 salário mínimo
# 8   Inserção no mercado de trabalho  Até 1,5 salário mínimo
# 9   Inserção no mercado de trabalho  Até 1,5 salário mínimo
# 10  Inserção no mercado de trabalho  Até 1,5 salário mínimo
# 11  Inserção no mercado de trabalho  Até 1,5 salário mínimo
# 12  Inserção no mercado de trabalho  Até 1,5 salário mínimo
# 13  Inserção no mercado de trabalho  Até 1,5 salário mínimo
# 14  Inserção no mercado de trabalho  Até 1,5 salário mínimo
# 15  Inserção no mercado de trabalho  Até 1,5 salário mínimo
# 16  Inserção no mercado de trabalho  Até 1,5 salário mínimo
# 17  Inserção no mercado de trabalho  Até 1,5 salário mínimo
# 18  Inserção no mercado de trabalho  Até 1,5 salário mínimo
# 19  Inserção no mercado de trabalho  Até 1,5 salário mínimo
#
#            horas_trabalho cotas  nota_geral  nota_formacao_geral  \
# 0   Não estou trabalhando   Não         0.0                  0.0
# 1   Não estou trabalhando   Não         0.0                  0.0
# 2   Não estou trabalhando   Não         0.0                  0.0
# 3   Não estou trabalhando   Não         0.0                  0.0
# 4   Não estou trabalhando   Não         0.0                  0.0
# 5   Não estou trabalhando   Não         0.0                  0.0
# 6   Não estou trabalhando   Não         0.0                  0.0
# 7   Não estou trabalhando   Não         0.0                  0.0
# 8   Não estou trabalhando   Não         0.0                  0.0
# 9   Não estou trabalhando   Não         0.0                  0.0
# 10  Não estou trabalhando   Não         0.0                  0.0
# 11  Não estou trabalhando   Não         0.0                  0.0
# 12  Não estou trabalhando   Não         0.0                  0.0
# 13  Não estou trabalhando   Não         0.0                  0.0
# 14  Não estou trabalhando   Não         0.0                  0.0
# 15  Não estou trabalhando   Não         0.0                  0.0
# 16  Não estou trabalhando   Não         0.0                  0.0
# 17  Não estou trabalhando   Não         0.0                  0.0
# 18  Não estou trabalhando   Não         0.0                  0.0
# 19  Não estou trabalhando   Não         0.0                  0.0
#
#     nota_componentes_especifico avaliacao_dificuldade_fg  \
# 0                           0.0                    Médio
# 1                           0.0         Resposta anulada
# 2                           0.0         Resposta anulada
# 3                           0.0         Resposta anulada
# 4                           0.0         Resposta anulada
# 5                           0.0         Resposta anulada
# 6                           0.0         Resposta anulada
# 7                           0.0         Resposta anulada
# 8                           0.0         Resposta anulada
# 9                           0.0         Resposta anulada
# 10                          0.0         Resposta anulada
# 11                          0.0         Resposta anulada
# 12                          0.0         Resposta anulada
# 13                          0.0         Resposta anulada
# 14                          0.0         Resposta anulada
# 15                          0.0         Resposta anulada
# 16                          0.0         Resposta anulada
# 17                          0.0         Resposta anulada
# 18                          0.0         Resposta anulada
# 19                          0.0         Resposta anulada
#
#    avaliacao_dificuldade_ce avaliacao_equipamentos     avaliacao_ambiente
# 0                     Médio    Discordo totalmente    Discordo totalmente
# 1          Resposta anulada    Discordo totalmente    Discordo totalmente
# 2          Resposta anulada    Discordo totalmente    Discordo totalmente
# 3          Resposta anulada    Discordo totalmente    Discordo totalmente
# 4          Resposta anulada    Discordo totalmente    Discordo totalmente
# 5          Resposta anulada    Discordo totalmente    Discordo totalmente
# 6          Resposta anulada    Discordo totalmente    Discordo totalmente
# 7          Resposta anulada    Discordo totalmente    Discordo totalmente
# 8          Resposta anulada  Discordo parcialmente  Discordo parcialmente
# 9          Resposta anulada    Discordo totalmente    Discordo totalmente
# 10         Resposta anulada    Discordo totalmente    Discordo totalmente
# 11         Resposta anulada  Discordo parcialmente  Discordo parcialmente
# 12         Resposta anulada    Discordo totalmente    Discordo totalmente
# 13         Resposta anulada    Discordo totalmente    Discordo totalmente
# 14         Resposta anulada    Discordo totalmente    Discordo totalmente
# 15         Resposta anulada    Discordo totalmente    Discordo totalmente
# 16         Resposta anulada    Discordo totalmente    Discordo totalmente
# 17         Resposta anulada    Discordo totalmente    Discordo totalmente
# 18         Resposta anulada    Discordo totalmente    Discordo totalmente
# 19         Resposta anulada    Discordo totalmente    Discordo totalmente

# %%
df_desnormalizado.to_csv("../enade_ready_to_use/enade_desnormalizado.csv", index=False, encoding="utf-8-sig")

# %%
df_desnormalizado = df_desnormalizado.sample(frac=0.1, random_state=42).reset_index(drop=True)
df_desnormalizado.head(5).to_csv("head.csv", index=False, encoding="utf-8-sig")

# %%
resumo = []

for col in df_desnormalizado.columns:
    s = df_desnormalizado[col]

    info = {
        "coluna": col,
        "dtype": str(s.dtype),
        "nulls_pct": round(s.isna().mean() * 100, 2)
    }

    if s.dtype == "object" or str(s.dtype).startswith("string"):
        info["max_len"] = int(s.astype(str).str.len().max())

    else:
        info["min"] = s.min()
        info["max"] = s.max()

    resumo.append(info)

df_resumo = pd.DataFrame(resumo)
df_resumo
