# %% [markdown]
# # Imports

# %%
import pandas as pd
import os

# %% [markdown]
# # Views

# %%
caminho_arquivo = r"C:\Users\Allan\Desktop\Enade18-23_Modificado\enade_desnormalizado.csv"
df = pd.read_csv(caminho_arquivo)
print(df.head())
# Out:
# C:\Users\Allan\AppData\Local\Temp\ipykernel_9272\2349812670.py:2: DtypeWarning: Columns (0: cor_raca, 1: tipo_escola_ensino_medio, 2: primeira_geracao, 3: escolaridade_pai, 4: escolaridade_mae, 5: motivacao_curso, 6: renda_familiar, 7: horas_trabalho, 8: cotas, 9: avaliacao_equipamentos, 10: avaliacao_ambiente) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(caminho_arquivo)
#    id_participacao  id_curso nome_curso categoria_administrativa  \
# 0                1         2    Direito          Pública Federal
# 1                2         2    Direito          Pública Federal
# 2                3         2    Direito          Pública Federal
# 3                4         2    Direito          Pública Federal
# 4                5         2    Direito          Pública Federal
#
#   modalidade_graduacao turno_graduacao  ano_enade  id_municipio  \
# 0           Presencial         Noturno       2018       5103403
# 1           Presencial         Noturno       2018       5103403
# 2           Presencial        Matutino       2018       5103403
# 3           Presencial         Noturno       2018       5103403
# 4           Presencial         Noturno       2018       5103403
#
#   nome_municipio  uf  ...          renda_familiar         horas_trabalho  \
# 0         CUIABA  MT  ...  Até 1,5 salário mínimo  Não estou trabalhando
# 1         CUIABA  MT  ...  Até 1,5 salário mínimo  Não estou trabalhando
# 2         CUIABA  MT  ...  Até 1,5 salário mínimo  Não estou trabalhando
# 3         CUIABA  MT  ...  Até 1,5 salário mínimo  Não estou trabalhando
# 4         CUIABA  MT  ...  Até 1,5 salário mínimo  Não estou trabalhando
#
#    cotas nota_geral  nota_formacao_geral  nota_componentes_especifico  \
# 0    Não        0.0                  0.0                          0.0
# 1    Não        0.0                  0.0                          0.0
# 2    Não        0.0                  0.0                          0.0
# 3    Não        0.0                  0.0                          0.0
# 4    Não        0.0                  0.0                          0.0
#
#   avaliacao_dificuldade_fg avaliacao_dificuldade_ce avaliacao_equipamentos  \
# 0                    Médio                    Médio    Discordo totalmente
# 1         Resposta anulada         Resposta anulada    Discordo totalmente
# 2         Resposta anulada         Resposta anulada    Discordo totalmente
# 3         Resposta anulada         Resposta anulada    Discordo totalmente
# 4         Resposta anulada         Resposta anulada    Discordo totalmente
#
#     avaliacao_ambiente
# 0  Discordo totalmente
# 1  Discordo totalmente
# 2  Discordo totalmente
# 3  Discordo totalmente
# 4  Discordo totalmente
#
# [5 rows x 31 columns]

# %%
print(f"Colunas: {df.columns.tolist()}")
# Out:
# Colunas: ['NU_ANO', 'CO_CATEGAD', 'CO_GRUPO', 'CO_MODALIDADE', 'CO_MUNIC_CURSO', 'CO_UF_CURSO', 'CO_REGIAO_CURSO', 'ANO_FIM_EM', 'ANO_IN_GRAD', 'CO_TURNO_GRADUACAO', 'NT_GER', 'NT_FG', 'NT_CE', 'CO_RS_I1', 'CO_RS_I2', 'QE_I62', 'QE_I63', 'TP_SEXO', 'NU_IDADE', 'QE_I02', 'QE_I04', 'QE_I05', 'QE_I08', 'QE_I10', 'QE_I15', 'QE_I17', 'QE_I21', 'QE_I25']

# %%
print(f"Informações do DataFrame:")
print(df.info())
# Out:
# Informações do DataFrame:
# <class 'pandas.DataFrame'>
# RangeIndex: 594013 entries, 0 to 594012
# Data columns (total 28 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   NU_ANO              594013 non-null  int64
#  1   CO_CATEGAD          594013 non-null  int64
#  2   CO_GRUPO            594013 non-null  int64
#  3   CO_MODALIDADE       594013 non-null  int64
#  4   CO_MUNIC_CURSO      594013 non-null  int64
#  5   CO_UF_CURSO         594013 non-null  int64
#  6   CO_REGIAO_CURSO     594013 non-null  int64
#  7   ANO_FIM_EM          593632 non-null  float64
#  8   ANO_IN_GRAD         593632 non-null  float64
#  9   CO_TURNO_GRADUACAO  593616 non-null  float64
#  10  NT_GER              411518 non-null  float64
#  11  NT_FG               411518 non-null  float64
#  12  NT_CE               411518 non-null  float64
#  13  CO_RS_I1            376250 non-null  str
#  14  CO_RS_I2            376250 non-null  str
#  15  QE_I62              475138 non-null  float64
#  16  QE_I63              475141 non-null  float64
#  17  TP_SEXO             593627 non-null  str
#  18  NU_IDADE            593632 non-null  float64
#  19  QE_I02              475227 non-null  str
#  20  QE_I04              475225 non-null  str
#  21  QE_I05              475227 non-null  str
#  22  QE_I08              475224 non-null  str
#  23  QE_I10              475223 non-null  str
#  24  QE_I15              475219 non-null  str
#  25  QE_I17              475218 non-null  str
#  26  QE_I21              475218 non-null  str
#  27  QE_I25              475207 non-null  str
# dtypes: float64(9), int64(7), str(12)
# memory usage: 133.1 MB
# None

# %%
print(f"Estatísticas descritivas:")
print(df.describe())
# Out:
# Estatísticas descritivas:
#          NU_ANO     CO_CATEGAD       CO_GRUPO  CO_MODALIDADE  CO_MUNIC_CURSO  \
# count  406294.0  406294.000000  406294.000000  406294.000000    4.062940e+05
# mean     2023.0       3.819697    1661.562337       0.838952    3.399210e+06
# std         0.0       1.811568    2652.055602       0.367576    9.031829e+05
# min      2023.0       1.000000       5.000000       0.000000    1.100023e+06
# 25%      2023.0       4.000000      19.000000       1.000000    2.927408e+06
# 50%      2023.0       4.000000      28.000000       1.000000    3.509502e+06
# 75%      2023.0       5.000000    5710.000000       1.000000    4.106902e+06
# max      2023.0       8.000000    6411.000000       1.000000    5.300108e+06
#
#          CO_UF_CURSO  CO_REGIAO_CURSO     ANO_FIM_EM    ANO_IN_GRAD  \
# count  406294.000000    406294.000000  406294.000000  406294.000000
# mean       33.821174         3.033185    2013.274316    2018.456308
# std         9.000160         0.988651       9.560146      21.402733
# min        11.000000         1.000000    1016.000000       4.000000
# 25%        29.000000         2.000000    2012.000000    2018.000000
# 50%        35.000000         3.000000    2016.000000    2019.000000
# 75%        41.000000         4.000000    2018.000000    2020.000000
# max        53.000000         5.000000    2914.000000    2090.000000
#
#        CO_TURNO_GRADUACAO         NT_GER          NT_FG          NT_CE  \
# count       406294.000000  346557.000000  346557.000000  346557.000000
# mean             3.141294      48.284498      50.433800      47.551091
# std              1.070052      15.380657      17.556206      17.251521
# min              1.000000       0.000000       0.000000       0.000000
# 25%              3.000000      36.800000      38.100000      34.600000
# 50%              3.000000      47.900000      50.600000      47.200000
# 75%              4.000000      59.400000      63.000000      60.200000
# max              4.000000      99.000000     100.000000     100.000000
#
#               QE_I62         QE_I63       NU_IDADE
# count  367696.000000  367695.000000  406294.000000
# mean        5.039032       5.142624      28.393013
# std         1.481986       1.403167       7.697058
# min         1.000000       1.000000      17.000000
# 25%         4.000000       5.000000      23.000000
# 50%         6.000000       6.000000      25.000000
# 75%         6.000000       6.000000      31.000000
# max         8.000000       8.000000      89.000000

# %%
print(f"valores nulos por coluna:")
print(df.isnull().mean() * 100)
# Out:
# valores nulos por coluna:
# id_participacao                 0.000000
# id_curso                        0.000000
# nome_curso                      0.000000
# categoria_administrativa        1.236497
# modalidade_graduacao            0.000000
# turno_graduacao                 0.993720
# ano_enade                       0.000000
# id_municipio                    0.000000
# nome_municipio                  0.000000
# uf                              0.000000
# regiao                          0.000000
# sexo                            0.033249
# idade                           0.033371
# cor_raca                       13.233666
# ano_fim_ensino_medio            0.046598
# ano_ingresso_graduacao          0.047730
# tipo_escola_ensino_medio       13.234313
# primeira_geracao               13.234515
# escolaridade_pai               13.233828
# escolaridade_mae               13.233666
# motivacao_curso                13.235486
# renda_familiar                 13.233828
# horas_trabalho                 13.233949
# cotas                          13.234475
# nota_geral                     20.524871
# nota_formacao_geral            20.524871
# nota_componentes_especifico    20.524871
# avaliacao_dificuldade_fg        0.000000
# avaliacao_dificuldade_ce        0.000000
# avaliacao_equipamentos         13.240704
# avaliacao_ambiente             13.240664
# dtype: float64

# %%
df["CO_CATEGAD"].value_counts(dropna=False)
# Out:
# CO_CATEGAD
# NaN    5688116
# 4.0     202936
# 1.0      75005
# 5.0      70660
# 8.0      30569
# 2.0      22549
# 3.0       2451
# 7.0       2124
# Name: count, dtype: int64
